# %% [markdown]
# ## Setup

# %%
# !pip install -q git+https://github.com/huggingface/transformers.git
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 96.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 83.5 MB/s eta 0:00:00
#   Building wheel for transformers (pyproject.toml) ... done

# %%
import requests
from PIL import Image
import io
import torch
import numpy as np
from torchvision import transforms
import pickle
from numpy import dot
from numpy.linalg import norm
import time
import os
from transformers import AutoImageProcessor, Mask2FormerForUniversalSegmentation
from pathlib import Path

# %%
# connect to drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
path = '/gdrive/MyDrive/berlin_bike_CV/'
folder = 'metadata'
tile_folder = 'labeled_tiles'
name = 'DSR'

# %% [markdown]
# # Print tiles to choose one for tile_quadkey

# %%
# load tiles edges file for tiles
file_name = '_tiles_edges.pkl'
file_path = os.path.join(path, folder, name + file_name)
with open(file_path, 'rb') as pickle_file:
    tiles_edges = pickle.load(pickle_file)
tiles = list(tiles_edges.keys())
print(tiles)
# Out:
# ['12021023233301', '12021023233303', '12021023233321', '12021023233323', '12021023233310', '12021023233312', '12021023233330', '12021023233332', '12021023233311', '12021023233313', '12021023233331', '12021023233333', '12021023322200', '12021023322202', '12021023322220', '12021023322222']

# %%
tile_quadkey = '12021023233303'

# %% [markdown]
# ## Function definitions

# %%
def load_mapillary_image(image_id):
# load image from mapillary based on image ID input

  # load mapillary access token
  file_path = '/gdrive/MyDrive/mapillary_token.txt'
  with open(file_path, 'r') as file:
      access_token = file.read()

  # request the URL of image
  header = {'Authorization' : 'OAuth {}'.format(access_token)}
  url = 'https://graph.mapillary.com/{}?fields=thumb_256_url'.format(image_id)
  r = requests.get(url, headers=header)
  data = r.json()
  image_url = data['thumb_256_url']

  # get image from URL
  image_data = requests.get(image_url, stream=True).content

  # convert image data to PIL Image
  image = Image.open(io.BytesIO(image_data))

  return image

# %%
def bike_lane_detection(image, processor, mask2former):
# load mask2former trained on Mapillary Vistas to detect potential bike lanes

  # prepare image for processing
  img = processor(images=image, return_tensors="pt").to(torch.device("cuda"))

  # Move mask2former to GPU
  mask2former.to(torch.device("cuda"))

  # run inference
  with torch.no_grad():
    outputs = mask2former(**img)

  # pass to processor for postprocessing
  predicted_map = processor.post_process_semantic_segmentation(outputs, target_sizes=[image.size[::-1]])[0]

  # check if it contains a bike lane
  unique_vals = predicted_map.unique()
  contains_bike_lane = torch.any(unique_vals == 7)

  return contains_bike_lane

# %%
# define image transformations
transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224), # new size will be 3x224x224
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225]
        )])

# %%
def get_image_features(img_unsqueezed, model):
# If it's a bike lane, extract features for bike lane label assignment

  # select layer for feature extraction
  my_layer = model.head

  # put model in evaluation mode for consistent results
  model.eval()

  # deactivate gradients
  for param in model.parameters():
     param.requires_grad = False

  # create hook on my_layer to get features
  features = []
  def hook(module, input, output):
      features.append(output)

  # Move the input tensor to the GPU
  img_unsqueezed = img_unsqueezed.to(torch.device("cuda"))

  # run foward pass
  hook_handle = my_layer.register_forward_hook(hook)  # Register the hook for the current layer
  out = model(img_unsqueezed)
  hook_handle.remove()  # Remove the hook after extracting features

  # extract features, convert to np array
  img_features = torch.squeeze(torch.flatten(features[0])).cpu().numpy()

  return img_features

# %%
def assign_bikelane_label(img_features):
# assing a safety-label to bike lane image based on cosine similarity to medoids

  # define cosine similarity function
  def cosine_similarity(a, b):
    return dot(a, b)/(norm(a)*norm(b))

  # Path to the medoid file
  file_path = "/gdrive/My Drive/berlin_bike_CV/final_project_first_images/labelled_images/dinoS14_bikelanes_medoids.pickle"

  # Load medoid features and labels
  with open(file_path, "rb") as myfile:
      medoids = pickle.load(myfile)

  # extract medoid features
  street_lane_medoid = medoids[1]['street_shared'] # bike lanes that are shared with cars on the road
  sidewalk_lane_medoid = medoids[1]['off_street'] # bike lanes that are separated and located on the side walk

  # compare medoids to our image using cosine similarity
  cos2street_lane = cosine_similarity(street_lane_medoid, img_features)
  cos2sidewalk_lane = cosine_similarity(sidewalk_lane_medoid, img_features)

  # find label. 0 and 1 are used for cobblestone vs. street so we use 2 and 3 here
  if cos2sidewalk_lane >= cos2street_lane:
    lane_label = 2 # safe bike lane
  elif cos2street_lane >  cos2sidewalk_lane:
    lane_label = 3 # unsafe bike lane
  else:
    print("Error: Lane comparison values are in wrong format!")
    assert False # stop script

  return lane_label

# %%
def road_surface_classification(img_unsqueezed, model):
# classify street image for cobblestone vs. asphalt

  # Move the input tensor to the GPU
  img_unsqueezed = img_unsqueezed.to(torch.device("cuda"))

  # run inference
  with torch.no_grad():
      predicted_label = model(img_unsqueezed)

  # Get the predicted class
  _, predicted_idx = torch.max(predicted_label, 1)
  _, label_index = torch.max(predicted_label, dim=1)
  my_index = label_index.item()
  labels = ['cobblestones', 'road']
  predicted_label = labels[my_index]

  return predicted_label, my_index

# %%
def run_image_labelling(image_id, processor, mask2former, dino, resnet):
# label image

  # labels
  my_labels = ['cobblestone', 'asphalt', 'safe bike lane', 'unsafe bike lane']

  # load image
  image = load_mapillary_image(image_id)

  # Is it a bike lane or not?
  contains_bike_lane = bike_lane_detection(image, processor, mask2former) # use raw image because Mask2Former has its own image processing

  # transform image for further processing in models
  img_t = transform(image)
  img_unsqueezed = torch.unsqueeze(img_t, 0) # add first singleton dimension, the 'batch'

  # if image contains bike lane, compare it to medoids
  if contains_bike_lane:
    print('   Image contains bike lane. Moving on to bike-lane labelling.')

    # extract features
    img_features = get_image_features(img_unsqueezed, dino)

    # assign label to bike lane
    output_label = assign_bikelane_label(img_features)

  else:
    print('   No bike lane detected. Check if it is a cobblestone street')
    predicted_label, output_label = road_surface_classification(img_unsqueezed, resnet)

  return image_id, output_label, image

# %% [markdown]
# ## Load Edges with selected Images

# %%
# load edges per tile with selected images
file_name = '_tiles_edges_with_images.pkl'
file_path = os.path.join(path, folder, name + file_name)
with open(file_path, 'rb') as pickle_file:
  tiles_images = pickle.load(pickle_file)


# create new dict for desired tile
tile_path = os.path.join(path, tile_folder, tile_quadkey + '_labeled.pkl')
# check if target file for this tile exists
if os.path.exists(tile_path):
  with open(tile_path, 'rb') as pickle_file:
    tile_labeled = pickle.load(pickle_file)
else:
  file_name = '_tiles_edges.pkl'
  file_path = os.path.join(path, folder, name + file_name)
  with open(file_path, 'rb') as pickle_file:
    tiles_edges = pickle.load(pickle_file)
  tile_labeled = tiles_edges[tile_quadkey]

# %% [markdown]
# ## Run image processing

# %%
# load all models outside loop for speed

# mask2former
processor = AutoImageProcessor.from_pretrained("facebook/mask2former-swin-large-mapillary-vistas-semantic")
mask2former = Mask2FormerForUniversalSegmentation.from_pretrained("facebook/mask2former-swin-large-mapillary-vistas-semantic")

# DinoV2
dino = torch.hub.load('facebookresearch/dinov2', 'dinov2_vits14').to(torch.device("cuda"))

# ResNet
model_path = '/gdrive/MyDrive/berlin_bike_CV/CobblestoneModel/normal_OvA_ResNet18.pt'
resnet = torch.load(model_path).to(torch.device("cuda"))
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/536 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/79.5k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/866M [00:00<?, ?B/s]
# Downloading: "https://github.com/facebookresearch/dinov2/zipball/main" to /root/.cache/torch/hub/main.zip
# WARNING:dinov2:xFormers not available
# WARNING:dinov2:xFormers not available
# Downloading: "https://dl.fbaipublicfiles.com/dinov2/dinov2_vits14/dinov2_vits14_pretrain.pth" to /root/.cache/torch/hub/checkpoints/dinov2_vits14_pretrain.pth
# 100%|██████████| 84.2M/84.2M [00:00<00:00, 143MB/s]

# %%
# run pipeline for one image and time it

for edge in tile_labeled:
  # inference only for not yet labeld edges
  #if not tile_labeled[edge]:
    print(f"Edge: {edge}")
    if tiles_images[tile_quadkey][edge]:
      for img in tiles_images[tile_quadkey][edge]:
        st = time.time()
        image_id = list(img.keys())[0]
        image_id_out, output_label, image = run_image_labelling(image_id, processor, mask2former, dino, resnet)
        print(f"   Image {image_id}: {output_label}")
        et = time.time()
        # get the execution time
        elapsed_time = et - st
        print('   Execution time:', elapsed_time, 'seconds')
        # TODO: if the image was useless, take next image
        if output_label != 1:
          break
      image_dict = {'image_id': image_id, 'label': output_label}
      image_dict.update(img[image_id])
      tile_labeled[edge].append(image_dict)
    else:
      image_dict = {'image_id': 0, 'label': -1}
      # with open(tile_path, 'wb') as pickle_file:
      #   pickle.dump(tile_labeled, pickle_file)
    print(f" final: {output_label}")




# # compare label to actual image
# my_labels = ['cobblestone', 'asphalt', 'safe bike lane', 'unsafe bike lane']
# print('This image shows ' +  my_labels[output_label])

# show image to check assigned label
# image
# Out:
# Edge: (17777144, 26736187, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 4383538628325619: 1
#    Execution time: 0.6591296195983887 seconds
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 932584354242292: 3
#    Execution time: 0.6335034370422363 seconds
#  final: 3
# Edge: (17777144, 9146906832, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 224928195703053: 1
#    Execution time: 0.59688401222229 seconds
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 494517728557079: 3
#    Execution time: 0.5776474475860596 seconds
#  final: 3
# Edge: (17777144, 1188808257, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 908379683603290: 1
#    Execution time: 0.4053771495819092 seconds
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 310320667151381: 3
#    Execution time: 0.38379669189453125 seconds
#  final: 3
# Edge: (17777145, 26736188, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 519019895778719: 1
#    Execution time: 0.361799955368042 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 838604893748489: 1
#    Execution time: 0.3492259979248047 seconds
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 1152288942236653: 2
#    Execution time: 0.3596174716949463 seconds
#  final: 2
# Edge: (17777145, 9146906825, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 931241501427574: 1
#    Execution time: 0.3701479434967041 seconds
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 795138201139682: 2
#    Execution time: 0.3447706699371338 seconds
#  final: 2
# Edge: (17777145, 4782446450, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 500313474455167: 1
#    Execution time: 0.3506953716278076 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 257203916692716: 1
#    Execution time: 0.3352978229522705 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 931241501427574: 1
#    Execution time: 0.356647253036499 seconds
#  final: 1
# Edge: (21487101, 26784929, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 504739150852753: 1
#    Execution time: 0.41600942611694336 seconds
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 1201559866971977: 3
#    Execution time: 0.36606597900390625 seconds
#  final: 3
# Edge: (21487101, 731825428, 0)
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 291383922615129: 2
#    Execution time: 0.2932472229003906 seconds
#  final: 2
# Edge: (26662367, 26662375, 0)
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 215514513323861: 2
#    Execution time: 0.30858564376831055 seconds
#  final: 2
# Edge: (26662367, 26662502, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 942336596584788: 1
#    Execution time: 0.2876908779144287 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 2667865456838257: 1
#    Execution time: 0.30414509773254395 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 136452055181503: 1
#    Execution time: 0.2945139408111572 seconds
#  final: 1
# Edge: (26662367, 26784933, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 468919600840629: 1
#    Execution time: 0.2921016216278076 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 526924372050142: 1
#    Execution time: 0.289736270904541 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 1149522065461434: 1
#    Execution time: 0.2944300174713135 seconds
#  final: 1
# Edge: (26662367, 2513403220, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 379754713340649: 1
#    Execution time: 0.29386353492736816 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 136452055181503: 1
#    Execution time: 0.28467845916748047 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 794342942081236: 1
#    Execution time: 0.30194735527038574 seconds
#  final: 1
# Edge: (26662375, 26784930, 0)
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 215514513323861: 2
#    Execution time: 0.3097679615020752 seconds
#  final: 2
# Edge: (26662375, 6333316368, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 790416284944579: 1
#    Execution time: 0.29287195205688477 seconds
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 215514513323861: 2
#    Execution time: 0.30226802825927734 seconds
#  final: 2
# Edge: (26662375, 26662367, 0)
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 215514513323861: 2
#    Execution time: 0.3137857913970947 seconds
#  final: 2
# Edge: (26662385, 919493824, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 2085014028308319: 1
#    Execution time: 0.28978490829467773 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 285009156634535: 1
#    Execution time: 0.2943155765533447 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 523378228846627: 1
#    Execution time: 0.32076597213745117 seconds
#  final: 1
# Edge: (26662385, 10941241838, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 311936203752467: 1
#    Execution time: 0.30947375297546387 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 4273477226017841: 1
#    Execution time: 0.32536911964416504 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 4163643503681422: 1
#    Execution time: 0.33617186546325684 seconds
#  final: 1
# Edge: (26662395, 9146906837, 0)
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 201779732275378: 2
#    Execution time: 0.36089253425598145 seconds
#  final: 2
# Edge: (26662395, 26736197, 0)
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 201779732275378: 2
#    Execution time: 0.3521547317504883 seconds
#  final: 2
# Edge: (26662404, 21487101, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 490219339067389: 1
#    Execution time: 0.38011813163757324 seconds
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 7001537183219918: 2
#    Execution time: 0.3596317768096924 seconds
#  final: 2
# Edge: (26662404, 425074063, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 246730618020295: 1
#    Execution time: 0.35858583450317383 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 166148295397647: 1
#    Execution time: 0.34522366523742676 seconds
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 1431347407223883: 2
#    Execution time: 0.34583449363708496 seconds
#  final: 2
# Edge: (26662404, 10840068123, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 246730618020295: 1
#    Execution time: 0.3483927249908447 seconds
#    Image contains bike lane. Moving on to bike-lane labelling.
#    Image 1431347407223883: 2
#    Execution time: 0.3913688659667969 seconds
#  final: 2
# Edge: (26662502, 26784917, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 1911165105697558: 1
#    Execution time: 0.4568953514099121 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 3913010348795019: 1
#    Execution time: 0.9013159275054932 seconds
#    No bike lane detected. Check if it is a cobblestone street
#    Image 495421845127902: 1
#    Execution time: 0.8469367027282715 seconds
#  final: 1
# Edge: (26662502, 433914770, 0)
#    No bike lane detected. Check if it is a cobblestone street
#    Image 166506091982026: 1
#    Execution time: 0.7502152919769287 seconds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-f90efeb6cf79> in <cell line: 3>()
#       9         st = time.time()
#      10         image_id = list(img.keys())[0]
# ---> 11         image_id_out, output_label, image = run_image_labelling(image_id, processor, mask2former, dino, resnet)
#      12         print(f"   Image {image_id}: {output_label}")
#      13         et = time.time()
#
# <ipython-input-23-8d605f1197bc> in run_image_labelling(image_id, processor, mask2former, dino, resnet)
#       9
#      10   # Is it a bike lane or not?
# ---> 11   contains_bike_lane = bike_lane_detection(image, processor, mask2former) # use raw image because Mask2Former has its own image processing
#      12
#      13   # transform image for further processing in models
#
# <ipython-input-8-d74ad0386e25> in bike_lane_detection(image, processor, mask2former)
#      10   # run inference
#      11   with torch.no_grad():
# ---> 12     outputs = mask2former(**img)
#      13
#      14   # pass to processor for postprocessing
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mask2former/modeling_mask2former.py in forward(self, pixel_values, mask_labels, class_labels, pixel_mask, output_hidden_states, output_auxiliary_logits, output_attentions, return_dict)
#    2494         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    2495
# -> 2496         outputs = self.model(
#    2497             pixel_values=pixel_values,
#    2498             pixel_mask=pixel_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mask2former/modeling_mask2former.py in forward(self, pixel_values, pixel_mask, output_hidden_states, output_attentions, return_dict)
#    2265             pixel_mask = torch.ones((batch_size, height, width), device=pixel_values.device)
#    2266
# -> 2267         pixel_level_module_output = self.pixel_level_module(
#    2268             pixel_values=pixel_values, output_hidden_states=output_hidden_states
#    2269         )
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mask2former/modeling_mask2former.py in forward(self, pixel_values, output_hidden_states)
#    1393
#    1394     def forward(self, pixel_values: Tensor, output_hidden_states: bool = False) -> Mask2FormerPixelLevelModuleOutput:
# -> 1395         backbone_features = self.encoder(pixel_values).feature_maps
#    1396         decoder_output = self.decoder(backbone_features, output_hidden_states=output_hidden_states)
#    1397
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/swin/modeling_swin.py in forward(self, pixel_values, output_hidden_states, output_attentions, return_dict)
#    1318         embedding_output, input_dimensions = self.embeddings(pixel_values)
#    1319
# -> 1320         outputs = self.encoder(
#    1321             embedding_output,
#    1322             input_dimensions,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/swin/modeling_swin.py in forward(self, hidden_states, input_dimensions, head_mask, output_attentions, output_hidden_states, output_hidden_states_before_downsampling, always_partition, return_dict)
#     837                 )
#     838             else:
# --> 839                 layer_outputs = layer_module(
#     840                     hidden_states, input_dimensions, layer_head_mask, output_attentions, always_partition
#     841                 )
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/swin/modeling_swin.py in forward(self, hidden_states, input_dimensions, head_mask, output_attentions, always_partition)
#     755             layer_head_mask = head_mask[i] if head_mask is not None else None
#     756
# --> 757             layer_outputs = layer_module(
#     758                 hidden_states, input_dimensions, layer_head_mask, output_attentions, always_partition
#     759             )
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/swin/modeling_swin.py in forward(self, hidden_states, input_dimensions, head_mask, output_attentions, always_partition)
#     710
#     711         layer_output = self.layernorm_after(hidden_states)
# --> 712         layer_output = self.intermediate(layer_output)
#     713         layer_output = hidden_states + self.output(layer_output)
#     714
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/swin/modeling_swin.py in forward(self, hidden_states)
#     577
#     578     def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 579         hidden_states = self.dense(hidden_states)
#     580         hidden_states = self.intermediate_act_fn(hidden_states)
#     581         return hidden_states
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     112
#     113     def forward(self, input: Tensor) -> Tensor:
# --> 114         return F.linear(input, self.weight, self.bias)
#     115
#     116     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1599             self._backward_pre_hooks = OrderedDict()
#    1600
# -> 1601     def __getattr__(self, name: str) -> Union[Tensor, 'Module']:
#    1602         if '_parameters' in self.__dict__:
#    1603             _parameters = self.__dict__['_parameters']
#
# KeyboardInterrupt:

# %%
# with open(tile_path, 'rb') as pickle_file:
#   tiles_labeled_reconstr = pickle.load(pickle_file)

# %%
# print(tiles_labeled_reconstr)
